# %% [markdown]
# # Assignment 4

# %% [markdown]
# prob 1.1: Write a Python Program(with class concepts) to find the area of the triangle using the below formula.
# area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
# Function to take the length of the sides of triangle from user should be defined in the parent class and function to calculate the area should be defined in subclass.

# %%
#Take input values from user
a = int(input('Please enter the first side of a triangle: '))
b = int(input('Please enter the second side of a triangle: '))
c = int(input('Please enter the third side of a triangle: '))
#parent class
class Triangle():
    def __init__(self,a,b,c):
        self.a = a
        self.b = b
        self.c = c
#child class        
class Area(Triangle):
    def __init__(self,*args):
        s=(a + b + c)/2
        area=((s*(s-a)*(s-b)*(s-c))**0.5)
        return area
t = triangle(a, b, c)
print("Area of triangle is : " , t.area())
# Out:
# Please enter the first side of a triangle: 2
# Please enter the second side of a triangle: 3
# Please enter the third side of a triangle: 4
# Area of triangle is :  2.9047375096555625

# %% [markdown]
#  prob 1.2: Write a function filter_long_words() that takes a list of words and an integer n and returns the list of words that are longer than n.

# %%
def filter_long_words(words_list):
    word_len= []
    newstr=[]
    for n in words_list:
        if type(n)==str:
            word_len.append(n) 
        else:
            n1=n
    for j in word_len:
        if len(j)>n1:
            newstr.append(j)
    return newstr     

print(filter_long_words(["anu","anasuya","prajith", "surya","Indugula","nandhini",6]))
# Out:
# ['anasuya', 'prajith', 'Indugula', 'nandhini']

# %% [markdown]
# prob 2.1:Write a Python program using function concept that maps  list of words into a list of integers representing the lengths of the corresponding words​.  Hint: ​If a list [ ab,cde,erty] is passed on to the python function output should come as [2,3,4]
# Here 2,3 and 4 are the lengths of the words in the list.

# %%
def lengthofword(words_list):
    word_len = []
    for n in words_list:
        word_len.append((len(n)))       
    return word_len

print(lengthofword(["anu","siri","surya","prajith"]))
# Out:
# [3, 4, 5, 7]

# %% [markdown]
# prob 2.2: Write a Python function which takes a character (i.e. a string of length 1) and returns True if it is a vowel, False otherwise.

# %%
#create a list of vowels
vowels=['a','e','i','o','u']
#create function to chech a character is vowel or not
def voc(w):
    for i in vowels:
        if(i==w):
            print("True")
            break
    else:
        print("False")

# %%
#Test for ovel
voc('u')
# Out:
# True

# %%
#test for constant
voc('m')
# Out:
# False

# %% [markdown]
#                                                         ****The end****
